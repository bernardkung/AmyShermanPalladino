# %%
import requests
import re
import os
import json
from bs4 import BeautifulSoup
from time import sleep
from random import normalvariate

# %% [markdown]
# Get the episode links
#
# - Go to show's episodes page
#     - Scrape the season dropdown for each individual season
#     - Scrape the season for an array of links to each episode page
# - Go to each episode page
#     - Scrape the episode for the runtime
# - Final array of arrays, each sub-array has:
#     - season number
#     - episode number
#     - episode link
#     - runtime (in minutes)

# %%
def politePause(sec):
    sleep(normalvariate(sec, sec/24))

# %%
def scrapeSeasons(episodes_url):
    # Scrape the given URL for an array of total seasons
    req = requests.get(episodes_url)
    soup = BeautifulSoup(req.text, 'html.parser')

    seasons = []
    raw_seasons = soup.find('select', {'id':'bySeason'}).find_all('option')
    for raw_season in raw_seasons:
        seasons.append(int(raw_season.get_text().strip()))
    
    return seasons

# %%
def scrapeEpisodeLinks(episodes_url, seasons, pause=2):
    # Scrape the given URL for an array of total episodes
    ep_list = []
    for season in seasons:
        # Scrape the season list
        season_url = episodes_url + "?season=" + str(season)
        req = requests.get(season_url)
        soup = BeautifulSoup(req.text, 'html.parser')

        # Find the list of links
        a_list = soup.find_all('a', {'itemprop': 'name'})

        # Build the output array
        for episode,a in enumerate(a_list):
            ep_dict = {
                "season": season, 
                "episode": episode+1,
                "link": a['href']
                }
            ep_list.append(ep_dict)
            print(ep_dict, flush=True)
            politePause(pause)
    
    return ep_list

# %%
def formatRuntime(raw_runtime):
    # Correct runtime from string format to int formatted minutes
    arr_runtime = raw_runtime.replace('Runtime', '').split(' ')
    if arr_runtime[1] == 'hour':
        runtime = int(arr_runtime[0])*60
    else:
        runtime = int(arr_runtime[0])
        
    return runtime

def scrapeRuntime(episode_url):
    # Scrape the provided episode URL for the runtime
    req = requests.get(episode_url)
    soup = BeautifulSoup(req.text, 'html.parser')

    # Get the runtime
    runtime = soup.find("li", {"data-testid": "title-techspec_runtime"}).get_text()

    return runtime

def scrapeRuntimes(ep_list, pause=2):
     for ep in ep_list:
        url = 'https://www.imdb.com' + ep['link']
        raw_runtime = scrapeRuntime(url)
        runtime = formatRuntime(raw_runtime)
        print(str(ep['season']) + 'x' + str(ep['episode']) + ": " + str(runtime), flush=True)
        ep['runtime'] = runtime

# %%
def main(url, filename):
    seasons = scrapeSeasons(url)
    ep_list = scrapeEpisodeLinks(url, seasons)
    scrapeRuntimes(ep_list)
    
    with open('./output/' + filename +'.json', 'w+') as outfile:
        json.dump(ep_list, outfile)

# %%
main('https://www.imdb.com/title/tt0238784/episodes', 'gilmoregirls')
# Out:
# {'season': 1, 'episode': 1, 'link': '/title/tt0931812/'}
# {'season': 1, 'episode': 2, 'link': '/title/tt0588176/'}
# {'season': 1, 'episode': 3, 'link': '/title/tt0588209/'}
# {'season': 1, 'episode': 4, 'link': '/title/tt0588157/'}
# {'season': 1, 'episode': 5, 'link': '/title/tt0588202/'}
# {'season': 1, 'episode': 6, 'link': '/title/tt0588129/'}
# {'season': 1, 'episode': 7, 'link': '/title/tt0588182/'}
# {'season': 1, 'episode': 8, 'link': '/title/tt0588158/'}
# {'season': 1, 'episode': 9, 'link': '/title/tt0588166/'}
# {'season': 1, 'episode': 10, 'link': '/title/tt0588183/'}
# {'season': 1, 'episode': 11, 'link': '/title/tt0588141/'}
# {'season': 1, 'episode': 12, 'link': '/title/tt0588175/'}
# {'season': 1, 'episode': 13, 'link': '/title/tt0588135/'}
# {'season': 1, 'episode': 14, 'link': '/title/tt0588131/'}
# {'season': 1, 'episode': 15, 'link': '/title/tt0588197/'}
# {'season': 1, 'episode': 16, 'link': '/title/tt0588128/'}
# {'season': 1, 'episode': 17, 'link': '/title/tt0588192/'}
# {'season': 1, 'episode': 18, 'link': '/title/tt0588201/'}
# {'season': 1, 'episode': 19, 'link': '/title/tt0588217/'}
# {'season': 1, 'episode': 20, 'link': '/title/tt0588138/'}
# {'season': 1, 'episode': 21, 'link': '/title/tt0588174/'}
# {'season': 1, 'episode': 22, 'link': '/title/tt0588167/'}
# {'season': 2, 'episode': 1, 'link': '/title/tt0588185/'}
# {'season': 2, 'episode': 2, 'link': '/title/tt0588144/'}
# {'season': 2, 'episode': 3, 'link': '/title/tt0588180/'}
# {'season': 2, 'episode': 4, 'link': '/title/tt0588216/'}
# {'season': 2, 'episode': 5, 'link': '/title/tt0588171/'}
# {'season': 2, 'episode': 6, 'link': '/title/tt0588177/'}
# {'season': 2, 'episode': 7, 'link': '/title/tt0588162/'}
# {'season': 2, 'episode': 8, 'link': '/title/tt0588208/'}
# {'season': 2, 'episode': 9, 'link': '/title/tt0588184/'}
# {'season': 2, 'episode': 10, 'link': '/title/tt0588200/'}
# {'season': 2, 'episode': 11, 'link': '/title/tt0588190/'}
# {'season': 2, 'episode': 12, 'link': '/title/tt0588181/'}
# {'season': 2, 'episode': 13, 'link': '/title/tt0588117/'}
# {'season': 2, 'episode': 14, 'link': '/title/tt0588153/'}
# {'season': 2, 'episode': 15, 'link': '/title/tt0588165/'}
# {'season': 2, 'episode': 16, 'link': '/title/tt0588219/'}
# {'season': 2, 'episode': 17, 'link': '/title/tt0588132/'}
# {'season': 2, 'episode': 18, 'link': '/title/tt0588122/'}
# {'season': 2, 'episode': 19, 'link': '/title/tt0588195/'}
# {'season': 2, 'episode': 20, 'link': '/title/tt0588147/'}
# {'season': 2, 'episode': 21, 'link': '/title/tt0588164/'}
# {'season': 2, 'episode': 22, 'link': '/title/tt0588150/'}
# {'season': 3, 'episode': 1, 'link': '/title/tt0588222/'}
# {'season': 3, 'episode': 2, 'link': '/title/tt0588205/'}
# {'season': 3, 'episode': 3, 'link': '/title/tt0588121/'}
# {'season': 3, 'episode': 4, 'link': '/title/tt0588173/'}
# {'season': 3, 'episode': 5, 'link': '/title/tt0588136/'}
# {'season': 3, 'episode': 6, 'link': '/title/tt0588194/'}
# {'season': 3, 'episode': 7, 'link': '/title/tt0588221/'}
# {'season': 3, 'episode': 8, 'link': '/title/tt0588161/'}
# {'season': 3, 'episode': 9, 'link': '/title/tt0588112/'}
# {'season': 3, 'episode': 10, 'link': '/title/tt0588198/'}
# {'season': 3, 'episode': 11, 'link': '/title/tt0588151/'}
# {'season': 3, 'episode': 12, 'link': '/title/tt0588163/'}
# {'season': 3, 'episode': 13, 'link': '/title/tt0588133/'}
# {'season': 3, 'episode': 14, 'link': '/title/tt0588193/'}
# {'season': 3, 'episode': 15, 'link': '/title/tt0588139/'}
# {'season': 3, 'episode': 16, 'link': '/title/tt0588199/'}
# {'season': 3, 'episode': 17, 'link': '/title/tt0588116/'}
# {'season': 3, 'episode': 18, 'link': '/title/tt0588145/'}
# {'season': 3, 'episode': 19, 'link': '/title/tt0588156/'}
# {'season': 3, 'episode': 20, 'link': '/title/tt0588187/'}
# {'season': 3, 'episode': 21, 'link': '/title/tt0588148/'}
# {'season': 3, 'episode': 22, 'link': '/title/tt0588220/'}
# {'season': 4, 'episode': 1, 'link': '/title/tt0588123/'}
# {'season': 4, 'episode': 2, 'link': '/title/tt0588210/'}
# {'season': 4, 'episode': 3, 'link': '/title/tt0588206/'}
# {'season': 4, 'episode': 4, 'link': '/title/tt0588127/'}
# {'season': 4, 'episode': 5, 'link': '/title/tt0588204/'}
# {'season': 4, 'episode': 6, 'link': '/title/tt0588120/'}
# {'season': 4, 'episode': 7, 'link': '/title/tt0588203/'}
# {'season': 4, 'episode': 8, 'link': '/title/tt0588134/'}
# {'season': 4, 'episode': 9, 'link': '/title/tt0588196/'}
# {'season': 4, 'episode': 10, 'link': '/title/tt0588211/'}
# {'season': 4, 'episode': 11, 'link': '/title/tt0588152/'}
# {'season': 4, 'episode': 12, 'link': '/title/tt0588113/'}
# {'season': 4, 'episode': 13, 'link': '/title/tt0588169/'}
# {'season': 4, 'episode': 14, 'link': '/title/tt0588207/'}
# {'season': 4, 'episode': 15, 'link': '/title/tt0588189/'}
# {'season': 4, 'episode': 16, 'link': '/title/tt0588215/'}
# {'season': 4, 'episode': 17, 'link': '/title/tt0588143/'}
# {'season': 4, 'episode': 18, 'link': '/title/tt0588223/'}
# {'season': 4, 'episode': 19, 'link': '/title/tt0588118/'}
# {'season': 4, 'episode': 20, 'link': '/title/tt0588168/'}
# {'season': 4, 'episode': 21, 'link': '/title/tt0588159/'}
# {'season': 4, 'episode': 22, 'link': '/title/tt0588179/'}
# {'season': 5, 'episode': 1, 'link': '/title/tt0588186/'}
# {'season': 5, 'episode': 2, 'link': '/title/tt0588115/'}
# {'season': 5, 'episode': 3, 'link': '/title/tt0588232/'}
# {'season': 5, 'episode': 4, 'link': '/title/tt0588224/'}
# {'season': 5, 'episode': 5, 'link': '/title/tt0588227/'}
# {'season': 5, 'episode': 6, 'link': '/title/tt0588172/'}
# {'season': 5, 'episode': 7, 'link': '/title/tt0588233/'}
# {'season': 5, 'episode': 8, 'link': '/title/tt0588212/'}
# {'season': 5, 'episode': 9, 'link': '/title/tt0588137/'}
# {'season': 5, 'episode': 10, 'link': '/title/tt0588126/'}
# {'season': 5, 'episode': 11, 'link': '/title/tt0588231/'}
# {'season': 5, 'episode': 12, 'link': '/title/tt0588130/'}
# {'season': 5, 'episode': 13, 'link': '/title/tt0588229/'}
# {'season': 5, 'episode': 14, 'link': '/title/tt0588188/'}
# {'season': 5, 'episode': 15, 'link': '/title/tt0588154/'}
# {'season': 5, 'episode': 16, 'link': '/title/tt0588191/'}
# {'season': 5, 'episode': 17, 'link': '/title/tt0588178/'}
# {'season': 5, 'episode': 18, 'link': '/title/tt0588225/'}
# {'season': 5, 'episode': 19, 'link': '/title/tt0588125/'}
# {'season': 5, 'episode': 20, 'link': '/title/tt0588149/'}
# {'season': 5, 'episode': 21, 'link': '/title/tt0588124/'}
# {'season': 5, 'episode': 22, 'link': '/title/tt0588114/'}
# {'season': 6, 'episode': 1, 'link': '/title/tt0588170/'}
# {'season': 6, 'episode': 2, 'link': '/title/tt0588140/'}
# {'season': 6, 'episode': 3, 'link': '/title/tt0588218/'}
# {'season': 6, 'episode': 4, 'link': '/title/tt0588119/'}
# {'season': 6, 'episode': 5, 'link': '/title/tt0588228/'}
# {'season': 6, 'episode': 6, 'link': '/title/tt0588230/'}
# {'season': 6, 'episode': 7, 'link': '/title/tt0588226/'}
# {'season': 6, 'episode': 8, 'link': '/title/tt0588160/'}
# {'season': 6, 'episode': 9, 'link': '/title/tt0588214/'}
# {'season': 6, 'episode': 10, 'link': '/title/tt0588146/'}
# {'season': 6, 'episode': 11, 'link': '/title/tt0588213/'}
# {'season': 6, 'episode': 12, 'link': '/title/tt0588155/'}
# {'season': 6, 'episode': 13, 'link': '/title/tt0588142/'}
# {'season': 6, 'episode': 14, 'link': '/title/tt0763165/'}
# {'season': 6, 'episode': 15, 'link': '/title/tt0757486/'}
# {'season': 6, 'episode': 16, 'link': '/title/tt0766823/'}
# {'season': 6, 'episode': 17, 'link': '/title/tt0766824/'}
# {'season': 6, 'episode': 18, 'link': '/title/tt0765894/'}
# {'season': 6, 'episode': 19, 'link': '/title/tt0778246/'}
# {'season': 6, 'episode': 20, 'link': '/title/tt0776994/'}
# {'season': 6, 'episode': 21, 'link': '/title/tt0794759/'}
# {'season': 6, 'episode': 22, 'link': '/title/tt0789988/'}
# {'season': 7, 'episode': 1, 'link': '/title/tt0824954/'}
# {'season': 7, 'episode': 2, 'link': '/title/tt0841271/'}
# {'season': 7, 'episode': 3, 'link': '/title/tt0847650/'}
# {'season': 7, 'episode': 4, 'link': '/title/tt0847649/'}
# {'season': 7, 'episode': 5, 'link': '/title/tt0861407/'}
# {'season': 7, 'episode': 6, 'link': '/title/tt0868143/'}
# {'season': 7, 'episode': 7, 'link': '/title/tt0868144/'}
# {'season': 7, 'episode': 8, 'link': '/title/tt0885841/'}
# {'season': 7, 'episode': 9, 'link': '/title/tt0888170/'}
# {'season': 7, 'episode': 10, 'link': '/title/tt0894094/'}
# {'season': 7, 'episode': 11, 'link': '/title/tt0901985/'}
# {'season': 7, 'episode': 12, 'link': '/title/tt0921218/'}
# {'season': 7, 'episode': 13, 'link': '/title/tt0957950/'}
# {'season': 7, 'episode': 14, 'link': '/title/tt0957949/'}
# {'season': 7, 'episode': 15, 'link': '/title/tt0949011/'}
# {'season': 7, 'episode': 16, 'link': '/title/tt0959778/'}
# {'season': 7, 'episode': 17, 'link': '/title/tt0976505/'}
# {'season': 7, 'episode': 18, 'link': '/title/tt0962360/'}
# {'season': 7, 'episode': 19, 'link': '/title/tt0993249/'}
# {'season': 7, 'episode': 20, 'link': '/title/tt1001863/'}
# {'season': 7, 'episode': 21, 'link': '/title/tt1009614/'}
# {'season': 7, 'episode': 22, 'link': '/title/tt1001862/'}
# 1x1: 44
# 1x2: 45
# 1x3: 44
# 1x4: 43
# 1x5: 44
# 1x6: 42
# 1x7: 45
# 1x8: 45
# 1x9: 45
# 1x10: 45
# 1x11: 43
# 1x12: 45
# 1x13: 42
# 1x14: 40
# 1x15: 45
# 1x16: 43
# 1x17: 45
# 1x18: 45
# 1x19: 45
# 1x20: 43
# 1x21: 44
# 1x22: 44
# 2x1: 42
# 2x2: 44
# 2x3: 44
# 2x4: 44
# 2x5: 45
# 2x6: 45
# 2x7: 45
# 2x8: 45
# 2x9: 44
# 2x10: 45
# 2x11: 44
# 2x12: 45
# 2x13: 43
# 2x14: 42
# 2x15: 42
# 2x16: 45
# 2x17: 45
# 2x18: 44
# 2x19: 45
# 2x20: 44
# 2x21: 43
# 2x22: 45
# 3x1: 45
# 3x2: 44
# 3x3: 44
# 3x4: 42
# 3x5: 44
# 3x6: 42
# 3x7: 44
# 3x8: 45
# 3x9: 42
# 3x10: 43
# 3x11: 42
# 3x12: 44
# 3x13: 42
# 3x14: 45
# 3x15: 45
# 3x16: 45
# 3x17: 45
# 3x18: 45
# 3x19: 44
# 3x20: 45
# 3x21: 44
# 3x22: 45
# 4x1: 44
# 4x2: 43
# 4x3: 60
# 4x4: 45
# 4x5: 60
# 4x6: 45
# 4x7: 45
# 4x8: 43
# 4x9: 45
# 4x10: 44
# 4x11: 44
# 4x12: 44
# 4x13: 44
# 4x14: 60
# 4x15: 42
# 4x16: 44
# 4x17: 44
# 4x18: 60
# 4x19: 44
# 4x20: 60
# 4x21: 44
# 4x22: 44
# 5x1: 44
# 5x2: 43
# 5x3: 44
# 5x4: 44
# 5x5: 44
# 5x6: 44
# 5x7: 44
# 5x8: 44
# 5x9: 44
# 5x10: 44
# 5x11: 44
# 5x12: 44
# 5x13: 44
# 5x14: 43
# 5x15: 44
# 5x16: 44
# 5x17: 44
# 5x18: 44
# 5x19: 44
# 5x20: 44
# 5x21: 44
# 5x22: 44
# 6x1: 44
# 6x2: 44
# 6x3: 45
# 6x4: 45
# 6x5: 45
# 6x6: 45
# 6x7: 44
# 6x8: 45
# 6x9: 45
# 6x10: 43
# 6x11: 45
# 6x12: 60
# 6x13: 45
# 6x14: 43
# 6x15: 42
# 6x16: 44
# 6x17: 44
# 6x18: 42
# 6x19: 60
# 6x20: 60
# 6x21: 60
# 6x22: 60
# 7x1: 43
# 7x2: 43
# 7x3: 43
# 7x4: 50
# 7x5: 43
# 7x6: 48
# 7x7: 47
# 7x8: 43
# 7x9: 43
# 7x10: 42
# 7x11: 42
# 7x12: 44
# 7x13: 47
# 7x14: 48
# 7x15: 43
# 7x16: 41
# 7x17: 47
# 7x18: 60
# 7x19: 60
# 7x20: 60
# 7x21: 60
# 7x22: 60

# %%
main('https://www.imdb.com/title/tt2006848/episodes', 'bunheads')
# Out:
# {'season': 1, 'episode': 1, 'link': '/title/tt2342525/'}
# {'season': 1, 'episode': 2, 'link': '/title/tt2166870/'}
# {'season': 1, 'episode': 3, 'link': '/title/tt2166872/'}
# {'season': 1, 'episode': 4, 'link': '/title/tt2162290/'}
# {'season': 1, 'episode': 5, 'link': '/title/tt2177886/'}
# {'season': 1, 'episode': 6, 'link': '/title/tt2228328/'}
# {'season': 1, 'episode': 7, 'link': '/title/tt2209310/'}
# {'season': 1, 'episode': 8, 'link': '/title/tt2257678/'}
# {'season': 1, 'episode': 9, 'link': '/title/tt2297452/'}
# {'season': 1, 'episode': 10, 'link': '/title/tt2310468/'}
# {'season': 1, 'episode': 11, 'link': '/title/tt2482916/'}
# {'season': 1, 'episode': 12, 'link': '/title/tt2614940/'}
# {'season': 1, 'episode': 13, 'link': '/title/tt2626494/'}
# {'season': 1, 'episode': 14, 'link': '/title/tt2633406/'}
# {'season': 1, 'episode': 15, 'link': '/title/tt2573908/'}
# {'season': 1, 'episode': 16, 'link': '/title/tt2633112/'}
# {'season': 1, 'episode': 17, 'link': '/title/tt2633128/'}
# {'season': 1, 'episode': 18, 'link': '/title/tt2702968/'}
# 1x1: 44
# 1x2: 44
# 1x3: 44
# 1x4: 44
# 1x5: 60
# 1x6: 60
# 1x7: 60
# 1x8: 44
# 1x9: 44
# 1x10: 44
# 1x11: 44
# 1x12: 44
# 1x13: 44
# 1x14: 44
# 1x15: 44
# 1x16: 44
# 1x17: 44
# 1x18: 44

# %%
main('https://www.imdb.com/title/tt5788792/episodes', 'maisel')
# Out:
# {'season': 1, 'episode': 1, 'link': '/title/tt6975526/'}
# {'season': 1, 'episode': 2, 'link': '/title/tt7113570/'}
# {'season': 1, 'episode': 3, 'link': '/title/tt6976082/'}
# {'season': 1, 'episode': 4, 'link': '/title/tt6997106/'}
# {'season': 1, 'episode': 5, 'link': '/title/tt7152106/'}
# {'season': 1, 'episode': 6, 'link': '/title/tt7086346/'}
# {'season': 1, 'episode': 7, 'link': '/title/tt7212460/'}
# {'season': 1, 'episode': 8, 'link': '/title/tt7267456/'}
# {'season': 2, 'episode': 1, 'link': '/title/tt7667344/'}
# {'season': 2, 'episode': 2, 'link': '/title/tt7690008/'}
# {'season': 2, 'episode': 3, 'link': '/title/tt7772296/'}
# {'season': 2, 'episode': 4, 'link': '/title/tt7772302/'}
# {'season': 2, 'episode': 5, 'link': '/title/tt7775670/'}
# {'season': 2, 'episode': 6, 'link': '/title/tt7775674/'}
# {'season': 2, 'episode': 7, 'link': '/title/tt7775676/'}
# {'season': 2, 'episode': 8, 'link': '/title/tt7667348/'}
# {'season': 2, 'episode': 9, 'link': '/title/tt7978458/'}
# {'season': 2, 'episode': 10, 'link': '/title/tt7978462/'}
# {'season': 3, 'episode': 1, 'link': '/title/tt8445866/'}
# {'season': 3, 'episode': 2, 'link': '/title/tt9487600/'}
# {'season': 3, 'episode': 3, 'link': '/title/tt9487628/'}
# {'season': 3, 'episode': 4, 'link': '/title/tt9487630/'}
# {'season': 3, 'episode': 5, 'link': '/title/tt9487632/'}
# {'season': 3, 'episode': 6, 'link': '/title/tt9487634/'}
# {'season': 3, 'episode': 7, 'link': '/title/tt9487636/'}
# {'season': 3, 'episode': 8, 'link': '/title/tt9487638/'}
# {'season': 4, 'episode': 1, 'link': '/title/tt11434042/'}
# {'season': 4, 'episode': 2, 'link': '/title/tt14613096/'}
# {'season': 4, 'episode': 3, 'link': '/title/tt14887058/'}
# {'season': 4, 'episode': 4, 'link': '/title/tt14544838/'}
# {'season': 4, 'episode': 5, 'link': '/title/tt15034776/'}
# {'season': 4, 'episode': 6, 'link': '/title/tt14912342/'}
# {'season': 4, 'episode': 7, 'link': '/title/tt15371904/'}
# {'season': 4, 'episode': 8, 'link': '/title/tt16479130/'}
# {'season': 5, 'episode': 1, 'link': '/title/tt18267152/'}
# 1x1: 56
# 1x2: 51
# 1x3: 49
# 1x4: 55
# 1x5: 47
# 1x6: 46
# 1x7: 51
# 1x8: 60
# 2x1: 54
# 2x2: 57
# 2x3: 47
# 2x4: 52
# 2x5: 52
# 2x6: 47
# 2x7: 54
# 2x8: 43
# 2x9: 52
# 2x10: 59
# 3x1: 58
# 3x2: 49
# 3x3: 53
# 3x4: 48
# 3x5: 55
# 3x6: 60
# 3x7: 57
# 3x8: 60
# 4x1: 55
# 4x2: 55
# 4x3: 60
# 4x4: 53
# 4x5: 59
# 4x6: 58
# 4x7: 53
# 4x8: 60
# 5x1: 57

# %%
## Manual run

# %%
episodes_url = 'https://www.imdb.com/title/tt0238784/episodes'

# %%
seasons = scrapeSeasons(episodes_url)
print(seasons)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
ep_list = scrapeEpisodeLinks(episodes_url, seasons)
# Out:
# {'season': 1, 'episode': 1, 'link': '/title/tt0931812/'}
# {'season': 1, 'episode': 2, 'link': '/title/tt0588176/'}
# {'season': 1, 'episode': 3, 'link': '/title/tt0588209/'}
# {'season': 1, 'episode': 4, 'link': '/title/tt0588157/'}
# {'season': 1, 'episode': 5, 'link': '/title/tt0588202/'}
# {'season': 1, 'episode': 6, 'link': '/title/tt0588129/'}
# {'season': 1, 'episode': 7, 'link': '/title/tt0588182/'}
# {'season': 1, 'episode': 8, 'link': '/title/tt0588158/'}
# {'season': 1, 'episode': 9, 'link': '/title/tt0588166/'}
# {'season': 1, 'episode': 10, 'link': '/title/tt0588183/'}
# {'season': 1, 'episode': 11, 'link': '/title/tt0588141/'}
# {'season': 1, 'episode': 12, 'link': '/title/tt0588175/'}
# {'season': 1, 'episode': 13, 'link': '/title/tt0588135/'}
# {'season': 1, 'episode': 14, 'link': '/title/tt0588131/'}
# {'season': 1, 'episode': 15, 'link': '/title/tt0588197/'}
# {'season': 1, 'episode': 16, 'link': '/title/tt0588128/'}
# {'season': 1, 'episode': 17, 'link': '/title/tt0588192/'}
# {'season': 1, 'episode': 18, 'link': '/title/tt0588201/'}
# {'season': 1, 'episode': 19, 'link': '/title/tt0588217/'}
# {'season': 1, 'episode': 20, 'link': '/title/tt0588138/'}
# {'season': 1, 'episode': 21, 'link': '/title/tt0588174/'}
# {'season': 1, 'episode': 22, 'link': '/title/tt0588167/'}
# {'season': 2, 'episode': 1, 'link': '/title/tt0588185/'}
# {'season': 2, 'episode': 2, 'link': '/title/tt0588144/'}
# {'season': 2, 'episode': 3, 'link': '/title/tt0588180/'}
# {'season': 2, 'episode': 4, 'link': '/title/tt0588216/'}
# {'season': 2, 'episode': 5, 'link': '/title/tt0588171/'}
# {'season': 2, 'episode': 6, 'link': '/title/tt0588177/'}
# {'season': 2, 'episode': 7, 'link': '/title/tt0588162/'}
# {'season': 2, 'episode': 8, 'link': '/title/tt0588208/'}
# {'season': 2, 'episode': 9, 'link': '/title/tt0588184/'}
# {'season': 2, 'episode': 10, 'link': '/title/tt0588200/'}
# {'season': 2, 'episode': 11, 'link': '/title/tt0588190/'}
# {'season': 2, 'episode': 12, 'link': '/title/tt0588181/'}
# {'season': 2, 'episode': 13, 'link': '/title/tt0588117/'}
# {'season': 2, 'episode': 14, 'link': '/title/tt0588153/'}
# {'season': 2, 'episode': 15, 'link': '/title/tt0588165/'}
# {'season': 2, 'episode': 16, 'link': '/title/tt0588219/'}
# {'season': 2, 'episode': 17, 'link': '/title/tt0588132/'}
# {'season': 2, 'episode': 18, 'link': '/title/tt0588122/'}
# {'season': 2, 'episode': 19, 'link': '/title/tt0588195/'}
# {'season': 2, 'episode': 20, 'link': '/title/tt0588147/'}
# {'season': 2, 'episode': 21, 'link': '/title/tt0588164/'}
# {'season': 2, 'episode': 22, 'link': '/title/tt0588150/'}
# {'season': 3, 'episode': 1, 'link': '/title/tt0588222/'}
# {'season': 3, 'episode': 2, 'link': '/title/tt0588205/'}
# {'season': 3, 'episode': 3, 'link': '/title/tt0588121/'}
# {'season': 3, 'episode': 4, 'link': '/title/tt0588173/'}
# {'season': 3, 'episode': 5, 'link': '/title/tt0588136/'}
# {'season': 3, 'episode': 6, 'link': '/title/tt0588194/'}
# {'season': 3, 'episode': 7, 'link': '/title/tt0588221/'}
# {'season': 3, 'episode': 8, 'link': '/title/tt0588161/'}
# {'season': 3, 'episode': 9, 'link': '/title/tt0588112/'}
# {'season': 3, 'episode': 10, 'link': '/title/tt0588198/'}
# {'season': 3, 'episode': 11, 'link': '/title/tt0588151/'}
# {'season': 3, 'episode': 12, 'link': '/title/tt0588163/'}
# {'season': 3, 'episode': 13, 'link': '/title/tt0588133/'}
# {'season': 3, 'episode': 14, 'link': '/title/tt0588193/'}
# {'season': 3, 'episode': 15, 'link': '/title/tt0588139/'}
# {'season': 3, 'episode': 16, 'link': '/title/tt0588199/'}
# {'season': 3, 'episode': 17, 'link': '/title/tt0588116/'}
# {'season': 3, 'episode': 18, 'link': '/title/tt0588145/'}
# {'season': 3, 'episode': 19, 'link': '/title/tt0588156/'}
# {'season': 3, 'episode': 20, 'link': '/title/tt0588187/'}
# {'season': 3, 'episode': 21, 'link': '/title/tt0588148/'}
# {'season': 3, 'episode': 22, 'link': '/title/tt0588220/'}
# {'season': 4, 'episode': 1, 'link': '/title/tt0588123/'}
# {'season': 4, 'episode': 2, 'link': '/title/tt0588210/'}
# {'season': 4, 'episode': 3, 'link': '/title/tt0588206/'}
# {'season': 4, 'episode': 4, 'link': '/title/tt0588127/'}
# {'season': 4, 'episode': 5, 'link': '/title/tt0588204/'}
# {'season': 4, 'episode': 6, 'link': '/title/tt0588120/'}
# {'season': 4, 'episode': 7, 'link': '/title/tt0588203/'}
# {'season': 4, 'episode': 8, 'link': '/title/tt0588134/'}
# {'season': 4, 'episode': 9, 'link': '/title/tt0588196/'}
# {'season': 4, 'episode': 10, 'link': '/title/tt0588211/'}
# {'season': 4, 'episode': 11, 'link': '/title/tt0588152/'}
# {'season': 4, 'episode': 12, 'link': '/title/tt0588113/'}
# {'season': 4, 'episode': 13, 'link': '/title/tt0588169/'}
# {'season': 4, 'episode': 14, 'link': '/title/tt0588207/'}
# {'season': 4, 'episode': 15, 'link': '/title/tt0588189/'}
# {'season': 4, 'episode': 16, 'link': '/title/tt0588215/'}
# {'season': 4, 'episode': 17, 'link': '/title/tt0588143/'}
# {'season': 4, 'episode': 18, 'link': '/title/tt0588223/'}
# {'season': 4, 'episode': 19, 'link': '/title/tt0588118/'}
# {'season': 4, 'episode': 20, 'link': '/title/tt0588168/'}
# {'season': 4, 'episode': 21, 'link': '/title/tt0588159/'}
# {'season': 4, 'episode': 22, 'link': '/title/tt0588179/'}
# {'season': 5, 'episode': 1, 'link': '/title/tt0588186/'}
# {'season': 5, 'episode': 2, 'link': '/title/tt0588115/'}
# {'season': 5, 'episode': 3, 'link': '/title/tt0588232/'}
# {'season': 5, 'episode': 4, 'link': '/title/tt0588224/'}
# {'season': 5, 'episode': 5, 'link': '/title/tt0588227/'}
# {'season': 5, 'episode': 6, 'link': '/title/tt0588172/'}
# {'season': 5, 'episode': 7, 'link': '/title/tt0588233/'}
# {'season': 5, 'episode': 8, 'link': '/title/tt0588212/'}
# {'season': 5, 'episode': 9, 'link': '/title/tt0588137/'}
# {'season': 5, 'episode': 10, 'link': '/title/tt0588126/'}
# {'season': 5, 'episode': 11, 'link': '/title/tt0588231/'}
# {'season': 5, 'episode': 12, 'link': '/title/tt0588130/'}
# {'season': 5, 'episode': 13, 'link': '/title/tt0588229/'}
# {'season': 5, 'episode': 14, 'link': '/title/tt0588188/'}
# {'season': 5, 'episode': 15, 'link': '/title/tt0588154/'}
# {'season': 5, 'episode': 16, 'link': '/title/tt0588191/'}
# {'season': 5, 'episode': 17, 'link': '/title/tt0588178/'}
# {'season': 5, 'episode': 18, 'link': '/title/tt0588225/'}
# {'season': 5, 'episode': 19, 'link': '/title/tt0588125/'}
# {'season': 5, 'episode': 20, 'link': '/title/tt0588149/'}
# {'season': 5, 'episode': 21, 'link': '/title/tt0588124/'}
# {'season': 5, 'episode': 22, 'link': '/title/tt0588114/'}
# {'season': 6, 'episode': 1, 'link': '/title/tt0588170/'}
# {'season': 6, 'episode': 2, 'link': '/title/tt0588140/'}
# {'season': 6, 'episode': 3, 'link': '/title/tt0588218/'}
# {'season': 6, 'episode': 4, 'link': '/title/tt0588119/'}
# {'season': 6, 'episode': 5, 'link': '/title/tt0588228/'}
# {'season': 6, 'episode': 6, 'link': '/title/tt0588230/'}
# {'season': 6, 'episode': 7, 'link': '/title/tt0588226/'}
# {'season': 6, 'episode': 8, 'link': '/title/tt0588160/'}
# {'season': 6, 'episode': 9, 'link': '/title/tt0588214/'}
# {'season': 6, 'episode': 10, 'link': '/title/tt0588146/'}
# {'season': 6, 'episode': 11, 'link': '/title/tt0588213/'}
# {'season': 6, 'episode': 12, 'link': '/title/tt0588155/'}
# {'season': 6, 'episode': 13, 'link': '/title/tt0588142/'}
# {'season': 6, 'episode': 14, 'link': '/title/tt0763165/'}
# {'season': 6, 'episode': 15, 'link': '/title/tt0757486/'}
# {'season': 6, 'episode': 16, 'link': '/title/tt0766823/'}
# {'season': 6, 'episode': 17, 'link': '/title/tt0766824/'}
# {'season': 6, 'episode': 18, 'link': '/title/tt0765894/'}
# {'season': 6, 'episode': 19, 'link': '/title/tt0778246/'}
# {'season': 6, 'episode': 20, 'link': '/title/tt0776994/'}
# {'season': 6, 'episode': 21, 'link': '/title/tt0794759/'}
# {'season': 6, 'episode': 22, 'link': '/title/tt0789988/'}
# {'season': 7, 'episode': 1, 'link': '/title/tt0824954/'}
# {'season': 7, 'episode': 2, 'link': '/title/tt0841271/'}
# {'season': 7, 'episode': 3, 'link': '/title/tt0847650/'}
# {'season': 7, 'episode': 4, 'link': '/title/tt0847649/'}
# {'season': 7, 'episode': 5, 'link': '/title/tt0861407/'}
# {'season': 7, 'episode': 6, 'link': '/title/tt0868143/'}
# {'season': 7, 'episode': 7, 'link': '/title/tt0868144/'}
# {'season': 7, 'episode': 8, 'link': '/title/tt0885841/'}
# {'season': 7, 'episode': 9, 'link': '/title/tt0888170/'}
# {'season': 7, 'episode': 10, 'link': '/title/tt0894094/'}
# {'season': 7, 'episode': 11, 'link': '/title/tt0901985/'}
# {'season': 7, 'episode': 12, 'link': '/title/tt0921218/'}
# {'season': 7, 'episode': 13, 'link': '/title/tt0957950/'}
# {'season': 7, 'episode': 14, 'link': '/title/tt0957949/'}
# {'season': 7, 'episode': 15, 'link': '/title/tt0949011/'}
# {'season': 7, 'episode': 16, 'link': '/title/tt0959778/'}
# {'season': 7, 'episode': 17, 'link': '/title/tt0976505/'}
# {'season': 7, 'episode': 18, 'link': '/title/tt0962360/'}
# {'season': 7, 'episode': 19, 'link': '/title/tt0993249/'}
# {'season': 7, 'episode': 20, 'link': '/title/tt1001863/'}
# {'season': 7, 'episode': 21, 'link': '/title/tt1009614/'}
# {'season': 7, 'episode': 22, 'link': '/title/tt1001862/'}

# %%
## Adjust EP list - There's an unaired pilot that needs to be removed from season 1
# Adjust episode numbers for season 1
for ep in ep_list:
    if ep['season']==1:
        ep['episode']=ep['episode']-1
# Remove unaired pilot
ep_list.pop(0)
# Out:
# {'season': 1, 'episode': 0, 'link': '/title/tt0931812/'}

# %%
scrapeRuntimes(ep_list)
# Out:
# 7x22: 60

# %%
ep_list
# Out:
# [{'season': 1, 'episode': 1, 'link': '/title/tt0588176/', 'runtime': 45},
#  {'season': 1, 'episode': 2, 'link': '/title/tt0588209/', 'runtime': 44},
#  {'season': 1, 'episode': 3, 'link': '/title/tt0588157/', 'runtime': 43},
#  {'season': 1, 'episode': 4, 'link': '/title/tt0588202/', 'runtime': 44},
#  {'season': 1, 'episode': 5, 'link': '/title/tt0588129/', 'runtime': 42},
#  {'season': 1, 'episode': 6, 'link': '/title/tt0588182/', 'runtime': 45},
#  {'season': 1, 'episode': 7, 'link': '/title/tt0588158/', 'runtime': 45},
#  {'season': 1, 'episode': 8, 'link': '/title/tt0588166/', 'runtime': 45},
#  {'season': 1, 'episode': 9, 'link': '/title/tt0588183/', 'runtime': 45},
#  {'season': 1, 'episode': 10, 'link': '/title/tt0588141/', 'runtime': 43},
#  {'season': 1, 'episode': 11, 'link': '/title/tt0588175/', 'runtime': 45},
#  {'season': 1, 'episode': 12, 'link': '/title/tt0588135/', 'runtime': 42},
#  {'season': 1, 'episode': 13, 'link': '/title/tt0588131/', 'runtime': 40},
#  {'season': 1, 'episode': 14, 'link': '/title/tt0588197/', 'runtime': 45},
#  {'season': 1, 'episode': 15, 'link': '/title/tt0588128/', 'runtime': 43},
#  {'season': 1, 'episode': 16, 'link': '/title/tt0588192/', 'runtime': 45},
#  {'season': 1, 'episode': 17, 'link': '/title/tt0588201/', 'runtime': 45},
#  {'season': 1, 'episode': 18, 'link': '/title/tt0588217/', 'runtime': 45},
#  {'season': 1, 'episode': 19, 'link': '/title/tt0588138/', 'runtime': 43},
#  {'season': 1, 'episode': 20, 'link': '/title/tt0588174/', 'runtime': 44},
#  {'season': 1, 'episode': 21, 'link': '/title/tt0588167/', 'runtime': 44},
#  {'season': 2, 'episode': 1, 'link': '/title/tt0588185/', 'runtime': 42},
#  {'season': 2, 'episode': 2, 'link': '/title/tt0588144/', 'runtime': 44},
#  {'season': 2, 'episode': 3, 'link': '/title/tt0588180/', 'runtime': 44},
#  {'season': 2, 'episode': 4, 'link': '/title/tt0588216/', 'runtime': 44},
#  {'season': 2, 'episode': 5, 'link': '/title/tt0588171/', 'runtime': 45},
#  {'season': 2, 'episode': 6, 'link': '/title/tt0588177/', 'runtime': 45},
#  {'season': 2, 'episode': 7, 'link': '/title/tt0588162/', 'runtime': 45},
#  {'season': 2, 'episode': 8, 'link': '/title/tt0588208/', 'runtime': 45},
#  {'season': 2, 'episode': 9, 'link': '/title/tt0588184/', 'runtime': 44},
#  {'season': 2, 'episode': 10, 'link': '/title/tt0588200/', 'runtime': 45},
#  {'season': 2, 'episode': 11, 'link': '/title/tt0588190/', 'runtime': 44},
#  {'season': 2, 'episode': 12, 'link': '/title/tt0588181/', 'runtime': 45},
#  {'season': 2, 'episode': 13, 'link': '/title/tt0588117/', 'runtime': 43},
#  {'season': 2, 'episode': 14, 'link': '/title/tt0588153/', 'runtime': 42},
#  {'season': 2, 'episode': 15, 'link': '/title/tt0588165/', 'runtime': 42},
#  {'season': 2, 'episode': 16, 'link': '/title/tt0588219/', 'runtime': 45},
#  {'season': 2, 'episode': 17, 'link': '/title/tt0588132/', 'runtime': 45},
#  {'season': 2, 'episode': 18, 'link': '/title/tt0588122/', 'runtime': 44},
#  {'season': 2, 'episode': 19, 'link': '/title/tt0588195/', 'runtime': 45},
#  {'season': 2, 'episode': 20, 'link': '/title/tt0588147/', 'runtime': 44},
#  {'season': 2, 'episode': 21, 'link': '/title/tt0588164/', 'runtime': 43},
#  {'season': 2, 'episode': 22, 'link': '/title/tt0588150/', 'runtime': 45},
#  {'season': 3, 'episode': 1, 'link': '/title/tt0588222/', 'runtime': 45},
#  {'season': 3, 'episode': 2, 'link': '/title/tt0588205/', 'runtime': 44},
#  {'season': 3, 'episode': 3, 'link': '/title/tt0588121/', 'runtime': 44},
#  {'season': 3, 'episode': 4, 'link': '/title/tt0588173/', 'runtime': 42},
#  {'season': 3, 'episode': 5, 'link': '/title/tt0588136/', 'runtime': 44},
#  {'season': 3, 'episode': 6, 'link': '/title/tt0588194/', 'runtime': 42},
#  {'season': 3, 'episode': 7, 'link': '/title/tt0588221/', 'runtime': 44},
#  {'season': 3, 'episode': 8, 'link': '/title/tt0588161/', 'runtime': 45},
#  {'season': 3, 'episode': 9, 'link': '/title/tt0588112/', 'runtime': 42},
#  {'season': 3, 'episode': 10, 'link': '/title/tt0588198/', 'runtime': 43},
#  {'season': 3, 'episode': 11, 'link': '/title/tt0588151/', 'runtime': 42},
#  {'season': 3, 'episode': 12, 'link': '/title/tt0588163/', 'runtime': 44},
#  {'season': 3, 'episode': 13, 'link': '/title/tt0588133/', 'runtime': 42},
#  {'season': 3, 'episode': 14, 'link': '/title/tt0588193/', 'runtime': 45},
#  {'season': 3, 'episode': 15, 'link': '/title/tt0588139/', 'runtime': 45},
#  {'season': 3, 'episode': 16, 'link': '/title/tt0588199/', 'runtime': 45},
#  {'season': 3, 'episode': 17, 'link': '/title/tt0588116/', 'runtime': 45},
#  {'season': 3, 'episode': 18, 'link': '/title/tt0588145/', 'runtime': 45},
#  {'season': 3, 'episode': 19, 'link': '/title/tt0588156/', 'runtime': 44},
#  {'season': 3, 'episode': 20, 'link': '/title/tt0588187/', 'runtime': 45},
#  {'season': 3, 'episode': 21, 'link': '/title/tt0588148/', 'runtime': 44},
#  {'season': 3, 'episode': 22, 'link': '/title/tt0588220/', 'runtime': 45},
#  {'season': 4, 'episode': 1, 'link': '/title/tt0588123/', 'runtime': 44},
#  {'season': 4, 'episode': 2, 'link': '/title/tt0588210/', 'runtime': 43},
#  {'season': 4, 'episode': 3, 'link': '/title/tt0588206/', 'runtime': 60},
#  {'season': 4, 'episode': 4, 'link': '/title/tt0588127/', 'runtime': 45},
#  {'season': 4, 'episode': 5, 'link': '/title/tt0588204/', 'runtime': 60},
#  {'season': 4, 'episode': 6, 'link': '/title/tt0588120/', 'runtime': 45},
#  {'season': 4, 'episode': 7, 'link': '/title/tt0588203/', 'runtime': 45},
#  {'season': 4, 'episode': 8, 'link': '/title/tt0588134/', 'runtime': 43},
#  {'season': 4, 'episode': 9, 'link': '/title/tt0588196/', 'runtime': 45},
#  {'season': 4, 'episode': 10, 'link': '/title/tt0588211/', 'runtime': 44},
#  {'season': 4, 'episode': 11, 'link': '/title/tt0588152/', 'runtime': 44},
#  {'season': 4, 'episode': 12, 'link': '/title/tt0588113/', 'runtime': 44},
#  {'season': 4, 'episode': 13, 'link': '/title/tt0588169/', 'runtime': 44},
#  {'season': 4, 'episode': 14, 'link': '/title/tt0588207/', 'runtime': 60},
#  {'season': 4, 'episode': 15, 'link': '/title/tt0588189/', 'runtime': 42},
#  {'season': 4, 'episode': 16, 'link': '/title/tt0588215/', 'runtime': 44},
#  {'season': 4, 'episode': 17, 'link': '/title/tt0588143/', 'runtime': 44},
#  {'season': 4, 'episode': 18, 'link': '/title/tt0588223/', 'runtime': 60},
#  {'season': 4, 'episode': 19, 'link': '/title/tt0588118/', 'runtime': 44},
#  {'season': 4, 'episode': 20, 'link': '/title/tt0588168/', 'runtime': 60},
#  {'season': 4, 'episode': 21, 'link': '/title/tt0588159/', 'runtime': 44},
#  {'season': 4, 'episode': 22, 'link': '/title/tt0588179/', 'runtime': 44},
#  {'season': 5, 'episode': 1, 'link': '/title/tt0588186/', 'runtime': 44},
#  {'season': 5, 'episode': 2, 'link': '/title/tt0588115/', 'runtime': 43},
#  {'season': 5, 'episode': 3, 'link': '/title/tt0588232/', 'runtime': 44},
#  {'season': 5, 'episode': 4, 'link': '/title/tt0588224/', 'runtime': 44},
#  {'season': 5, 'episode': 5, 'link': '/title/tt0588227/', 'runtime': 44},
#  {'season': 5, 'episode': 6, 'link': '/title/tt0588172/', 'runtime': 44},
#  {'season': 5, 'episode': 7, 'link': '/title/tt0588233/', 'runtime': 44},
#  {'season': 5, 'episode': 8, 'link': '/title/tt0588212/', 'runtime': 44},
#  {'season': 5, 'episode': 9, 'link': '/title/tt0588137/', 'runtime': 44},
#  {'season': 5, 'episode': 10, 'link': '/title/tt0588126/', 'runtime': 44},
#  {'season': 5, 'episode': 11, 'link': '/title/tt0588231/', 'runtime': 44},
#  {'season': 5, 'episode': 12, 'link': '/title/tt0588130/', 'runtime': 44},
#  {'season': 5, 'episode': 13, 'link': '/title/tt0588229/', 'runtime': 44},
#  {'season': 5, 'episode': 14, 'link': '/title/tt0588188/', 'runtime': 43},
#  {'season': 5, 'episode': 15, 'link': '/title/tt0588154/', 'runtime': 44},
#  {'season': 5, 'episode': 16, 'link': '/title/tt0588191/', 'runtime': 44},
#  {'season': 5, 'episode': 17, 'link': '/title/tt0588178/', 'runtime': 44},
#  {'season': 5, 'episode': 18, 'link': '/title/tt0588225/', 'runtime': 44},
#  {'season': 5, 'episode': 19, 'link': '/title/tt0588125/', 'runtime': 44},
#  {'season': 5, 'episode': 20, 'link': '/title/tt0588149/', 'runtime': 44},
#  {'season': 5, 'episode': 21, 'link': '/title/tt0588124/', 'runtime': 44},
#  {'season': 5, 'episode': 22, 'link': '/title/tt0588114/', 'runtime': 44},
#  {'season': 6, 'episode': 1, 'link': '/title/tt0588170/', 'runtime': 44},
#  {'season': 6, 'episode': 2, 'link': '/title/tt0588140/', 'runtime': 44},
#  {'season': 6, 'episode': 3, 'link': '/title/tt0588218/', 'runtime': 45},
#  {'season': 6, 'episode': 4, 'link': '/title/tt0588119/', 'runtime': 45},
#  {'season': 6, 'episode': 5, 'link': '/title/tt0588228/', 'runtime': 45},
#  {'season': 6, 'episode': 6, 'link': '/title/tt0588230/', 'runtime': 45},
#  {'season': 6, 'episode': 7, 'link': '/title/tt0588226/', 'runtime': 44},
#  {'season': 6, 'episode': 8, 'link': '/title/tt0588160/', 'runtime': 45},
#  {'season': 6, 'episode': 9, 'link': '/title/tt0588214/', 'runtime': 45},
#  {'season': 6, 'episode': 10, 'link': '/title/tt0588146/', 'runtime': 43},
#  {'season': 6, 'episode': 11, 'link': '/title/tt0588213/', 'runtime': 45},
#  {'season': 6, 'episode': 12, 'link': '/title/tt0588155/', 'runtime': 60},
#  {'season': 6, 'episode': 13, 'link': '/title/tt0588142/', 'runtime': 45},
#  {'season': 6, 'episode': 14, 'link': '/title/tt0763165/', 'runtime': 43},
#  {'season': 6, 'episode': 15, 'link': '/title/tt0757486/', 'runtime': 42},
#  {'season': 6, 'episode': 16, 'link': '/title/tt0766823/', 'runtime': 44},
#  {'season': 6, 'episode': 17, 'link': '/title/tt0766824/', 'runtime': 44},
#  {'season': 6, 'episode': 18, 'link': '/title/tt0765894/', 'runtime': 42},
#  {'season': 6, 'episode': 19, 'link': '/title/tt0778246/', 'runtime': 60},
#  {'season': 6, 'episode': 20, 'link': '/title/tt0776994/', 'runtime': 60},
#  {'season': 6, 'episode': 21, 'link': '/title/tt0794759/', 'runtime': 60},
#  {'season': 6, 'episode': 22, 'link': '/title/tt0789988/', 'runtime': 60},
#  {'season': 7, 'episode': 1, 'link': '/title/tt0824954/', 'runtime': 43},
#  {'season': 7, 'episode': 2, 'link': '/title/tt0841271/', 'runtime': 43},
#  {'season': 7, 'episode': 3, 'link': '/title/tt0847650/', 'runtime': 43},
#  {'season': 7, 'episode': 4, 'link': '/title/tt0847649/', 'runtime': 50},
#  {'season': 7, 'episode': 5, 'link': '/title/tt0861407/', 'runtime': 43},
#  {'season': 7, 'episode': 6, 'link': '/title/tt0868143/', 'runtime': 48},
#  {'season': 7, 'episode': 7, 'link': '/title/tt0868144/', 'runtime': 47},
#  {'season': 7, 'episode': 8, 'link': '/title/tt0885841/', 'runtime': 43},
#  {'season': 7, 'episode': 9, 'link': '/title/tt0888170/', 'runtime': 43},
#  {'season': 7, 'episode': 10, 'link': '/title/tt0894094/', 'runtime': 42},
#  {'season': 7, 'episode': 11, 'link': '/title/tt0901985/', 'runtime': 42},
#  {'season': 7, 'episode': 12, 'link': '/title/tt0921218/', 'runtime': 44},
#  {'season': 7, 'episode': 13, 'link': '/title/tt0957950/', 'runtime': 47},
#  {'season': 7, 'episode': 14, 'link': '/title/tt0957949/', 'runtime': 48},
#  {'season': 7, 'episode': 15, 'link': '/title/tt0949011/', 'runtime': 43},
#  {'season': 7, 'episode': 16, 'link': '/title/tt0959778/', 'runtime': 41},
#  {'season': 7, 'episode': 17, 'link': '/title/tt0976505/', 'runtime': 47},
#  {'season': 7, 'episode': 18, 'link': '/title/tt0962360/', 'runtime': 60},
#  {'season': 7, 'episode': 19, 'link': '/title/tt0993249/', 'runtime': 60},
#  {'season': 7, 'episode': 20, 'link': '/title/tt1001863/', 'runtime': 60},
#  {'season': 7, 'episode': 21, 'link': '/title/tt1009614/', 'runtime': 60},
#  {'season': 7, 'episode': 22, 'link': '/title/tt1001862/', 'runtime': 60}]

# %%
with open('./output/gg_runtimes.json', 'w+') as outfile:
        json.dump(ep_list, outfile)
